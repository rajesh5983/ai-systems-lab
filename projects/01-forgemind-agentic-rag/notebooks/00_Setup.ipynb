# %%
# Install required packages
import subprocess
import sys

packages = [
    'openai',
    'langchain', 
    'langflow',
    'langchain-community',
    'langchain-openai',
    'chromadb',
    'python-dotenv',
    'requests'
]

print("Installing required packages...")
for package in packages:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", package])
print("✓ All packages installed successfully!")

# %%
# Configure API Keys
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Verify API keys are configured
openai_key = os.getenv('OPENAI_API_KEY')

print("Environment Configuration Check:")
print(f"✓ OpenAI API Key configured: {bool(openai_key)}")

if not openai_key:
    print("\n⚠️  Warning: OpenAI API key is not configured!")
    print("Please create a .env file with your API key or set environment variables.")
else:
    print("\n✅ OpenAI API key is configured. Ready to start the course!")

# %%
import pandas as pd
import requests
from pathlib import Path

manifest = pd.read_csv("../data/manifests/pdf_manifest.csv")

kb_path = Path("../data/knowledge_base")
kb_path.mkdir(parents=True, exist_ok=True)

for _, row in manifest.iterrows():
    if row["active"] != "Y":
        continue

    url = row["source_url"]
    file_path = kb_path / row["file_name"]

    if file_path.exists():
        print("Skipping existing:", file_path)
        continue

    print("Downloading:", row["title"])

    r = requests.get(url)
    with open(file_path, "wb") as f:
        f.write(r.content)

print("Download complete.")
# Out:
# Skipping existing: ../data/knowledge_base/M0064766EN-US.pdf
# Skipping existing: ../data/knowledge_base/M0073563EN-US.pdf
# Skipping existing: ../data/knowledge_base/M0086975EN-US.pdf
# Skipping existing: ../data/knowledge_base/M0086990EN-US.pdf
# Skipping existing: ../data/knowledge_base/diesel-engine-fundamentals.pdf
# Downloading: OSHA Heavy Equipment Safety Guide
# Download complete.

# %%
manifest[["doc_id", "title", "source_url"]]
# Out:
#     doc_id                                     title  \
# 0   DOC001  730C2 Articulated Truck Operation Manual
# 1   DOC002      Hydraulic Excavator Operation Manual
# 2   DOC003             Wheel Loader Operation Manual
# 3   DOC004                 D6 Dozer Operation Manual
# 4   DOC005                Diesel Engine Fundamentals
# 5   DOC006              Cat Engine Diagnostics Guide
# 6   DOC007           Hydraulic Troubleshooting Guide
# 7   DOC008          Eaton Hydraulics Training Manual
# 8   DOC009            Surface Mining Equipment Guide
# 9   DOC010          Heavy Equipment Operations Guide
# 10  DOC011              Predictive Maintenance Guide
# 11  DOC012          Maintenance Best Practices Guide
# 12  DOC013      Managing Risks of Plant in Workplace
# 13  DOC014         OSHA Heavy Equipment Safety Guide
# 14  DOC015         Industrial Machinery Safety Guide
#
#                                            source_url
# 0   https://www.catpublications.com/previews/M0064...
# 1   https://www.catpublications.com/previews/M0073...
# 2   https://www.catpublications.com/previews/M0086...
# 3   https://www.catpublications.com/previews/M0086...
# 4   https://www.egr.msu.edu/classes/me201/somerton...
# 5   https://www.cat.com/content/dam/cat/en_us/supp...
# 6   https://www.parker.com/literature/Hydraulic%20...
# 7   https://www.eaton.com/content/dam/eaton/produc...
# 8   https://www.cdc.gov/niosh/mining/UserFiles/wor...
# 9   https://www.fhwa.dot.gov/construction/pubs/hif...
# 10  https://www.mckinsey.com/~/media/McKinsey/Busi...
# 11  https://www.plantengineering.com/assets/Upload...
# 12  https://www.safeworkaustralia.gov.au/system/fi...
# 13  https://www.osha.gov/sites/default/files/publi...
# 14           https://www.hse.gov.uk/pubns/indg229.pdf
